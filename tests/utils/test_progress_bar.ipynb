# %%
# from test_progress_bar import _test_tui
# from pathlib import Path
# _test_tui(Path("/tmp/"))

# %%
from test_progress_bar import _test_tui_remote
from pathlib import Path
_test_tui_remote(Path("/tmp/"))
# Out:
# 2023-06-29 20:26:50,923	INFO worker.py:1342 -- Connecting to existing Ray cluster at address: 10.138.0.10:6379...
# 2023-06-29 20:26:50,934	INFO worker.py:1519 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# HTML(value='')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from test_progress_bar import _test_tui_remote
#       2 from pathlib import Path
# ----> 3 _test_tui_remote(Path("/tmp/"))
#
# File ~/ablator/tests/utils/test_progress_bar.py:134, in _test_tui_remote(tmp_path)
#     132 done_id, remotes = ray.wait(remotes, num_returns=1, timeout=0.1)
#     133 dis.refresh()
# --> 134 time.sleep(random.random() / 10)
#
# KeyboardInterrupt:
